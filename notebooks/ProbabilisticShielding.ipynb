# %% [markdown]
# # Probabilistic Shielding

# %%
from sb3_contrib import MaskablePPO
from sb3_contrib.common.wrappers import ActionMasker
from stable_baselines3.common.logger import Logger, CSVOutputFormat, TensorBoardOutputFormat, HumanOutputFormat

import gymnasium as gym

from minigrid.core.actions import Actions
from minigrid.core.constants import TILE_PIXELS
from minigrid.wrappers import RGBImgObsWrapper, ImgObsWrapper

import tempfile, datetime, shutil

import time
import os

from utils import MiniGridShieldHandler, create_log_dir, ShieldingConfig, MiniWrapper, expname, shield_needed, shielded_evaluation, create_shield_overlay_image
from sb3utils import MiniGridSbShieldingWrapper, parse_sb3_arguments, InfoCallback

import os, sys
from copy import deepcopy

from PIL import Image
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.10.12)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 2025-10-22 09:06:08.461305: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-22 09:06:08.958602: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/venv/lib/python3.10/site-packages/cv2/../../lib64:
# 2025-10-22 09:06:08.958638: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2025-10-22 09:06:09.027342: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-10-22 09:06:10.356792: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/venv/lib/python3.10/site-packages/cv2/../../lib64:
# 2025-10-22 09:06:10.357222: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/venv/lib/python3.10/site-packages/cv2/../../lib64:
# 2025-10-22 09:06:10.357238: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
GRID_TO_PRISM_BINARY=os.getenv("M2P_BINARY")

def mask_fn(env: gym.Env):
    return env.create_action_mask()

def nomask_fn(env: gym.Env):
    return [1.0] * 7

def main():
    env = "MiniGrid-WindyCity2-v0"
    formula = "Pmax=? [G ! AgentIsOnLava]"
    shield_comparison =  "absolute"

    # The value used for training is 1.0 - epsilon from the paper
    value_for_training = 1.0
    shielding = ShieldingConfig.Training # change to ShieldingConfig.Disabled to run unshielded

    
    logger = Logger("/tmp", output_formats=[HumanOutputFormat(sys.stdout)])
    
    env = gym.make(env, render_mode="rgb_array")
    image_env = RGBImgObsWrapper(env, TILE_PIXELS)
    env = RGBImgObsWrapper(env, 8)
    env = ImgObsWrapper(env)
    env = MiniWrapper(env)

    
    env.reset()
    Image.fromarray(env.render()).show()
    
    shield_handlers = dict()
    if shield_needed(shielding):
        for value in [0.95, 0.97, 1.0]:
            shield_handler = MiniGridShieldHandler(GRID_TO_PRISM_BINARY, "grid.txt", "grid.prism", formula, shield_value=value, shield_comparison=shield_comparison, nocleanup=True, prism_file=None)
            env = MiniGridSbShieldingWrapper(env, shield_handler=shield_handler, create_shield_at_reset=False)


            shield_handlers[value] = shield_handler
    if shield_needed(shielding):
        for value in [0.95, 0.97, 1.0]:            
            create_shield_overlay_image(image_env, shield_handlers[value].create_shield())
            print(f"The shield for shield_value = {value}")

    if shielding == ShieldingConfig.Training:
        env = MiniGridSbShieldingWrapper(env, shield_handler=shield_handlers[value_for_training], create_shield_at_reset=False)
        env = ActionMasker(env, mask_fn)
        print("Training with shield:")
        create_shield_overlay_image(image_env, shield_handlers[value_for_training].create_shield())
    elif shielding == ShieldingConfig.Disabled:
        env = ActionMasker(env, nomask_fn)
    else:
        assert(False) 
    model = MaskablePPO("CnnPolicy", env, verbose=1, device="auto")
    model.set_logger(logger)
    steps = 400000

    model.learn(steps,callback=[InfoCallback()])



if __name__ == '__main__':
    print("Starting the training")
    main()
# Out:
# Starting the training
# /opt/venv/lib/python3.10/site-packages/gymnasium/core.py:297: UserWarning: WARN: env.get_frame to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_frame` for environment variables or `env.get_attr('get_frame')` that will search the reminding wrappers.
#   logger.warn(
# <PIL.Image.Image image mode=RGB size=864x704>
# /opt/venv/lib/python3.10/site-packages/gymnasium/core.py:297: UserWarning: WARN: env.printGrid to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.printGrid` for environment variables or `env.get_attr('printGrid')` that will search the reminding wrappers.
#   logger.warn(
# Computing new shield
# LOG: Starting with explicit model creation...
# Elapsed time is 2.8205628395080566 seconds.
# LOG: Starting with model checking...
# Elapsed time is 0.018934249877929688 seconds.
# Write to file shielding_files_20251022T090621_m4cug1h2/shield.
# LOG: Starting to translate shield...
# Elapsed time is 0.12146782875061035 seconds.
#
#
# Computing new shield
# LOG: Starting with explicit model creation...
# Elapsed time is 2.4319653511047363 seconds.
# LOG: Starting with model checking...
# Elapsed time is 0.001855611801147461 seconds.
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 683
# LOG: Starting to translate shield...
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 1139
# Write to file shielding_files_20251022T090625__ucshja5/shield.
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 683
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 1139
# Elapsed time is 0.10819125175476074 seconds.
#
#
# Computing new shield
# LOG: Starting with explicit model creation...
# Elapsed time is 2.390568971633911 seconds.
# LOG: Starting with model checking...
# Elapsed time is 0.002351999282836914 seconds.
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 610
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 611
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 635
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 659
# LOG: Starting to translate shield...
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 683
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 1139
# Write to file shielding_files_20251022T090628_pg881v9g/shield.
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 610
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 611
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 635
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 659
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 683
#  WARN (PreShield.cpp:50): No shielding action possible with absolute comparison for state with index 1139
# Elapsed time is 0.12406253814697266 seconds.
# /opt/venv/lib/python3.10/site-packages/gymnasium/core.py:297: UserWarning: WARN: env.width to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.width` for environment variables or `env.get_attr('width')` that will search the reminding wrappers.
#   logger.warn(
# /opt/venv/lib/python3.10/site-packages/gymnasium/core.py:297: UserWarning: WARN: env.height to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.height` for environment variables or `env.get_attr('height')` that will search the reminding wrappers.
#   logger.warn(
# <PIL.Image.Image image mode=RGBA size=864x704>
# The shield for shield_value = 0.95
# <PIL.Image.Image image mode=RGBA size=864x704>
# The shield for shield_value = 0.97
# <PIL.Image.Image image mode=RGBA size=864x704>
# The shield for shield_value = 1.0
# Training with shield:
# <PIL.Image.Image image mode=RGBA size=864x704>
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# /opt/venv/lib/python3.10/site-packages/gymnasium/core.py:297: UserWarning: WARN: env.get_frame to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_frame` for environment variables or `env.get_attr('get_frame')` that will search the reminding wrappers.
#   logger.warn(
# /opt/venv/lib/python3.10/site-packages/gymnasium/core.py:297: UserWarning: WARN: env.action_masks to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.action_masks` for environment variables or `env.get_attr('action_masks')` that will search the reminding wrappers.
#   logger.warn(
# /opt/venv/lib/python3.10/site-packages/gymnasium/core.py:297: UserWarning: WARN: env.get_symbolic_state to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.get_symbolic_state` for environment variables or `env.get_attr('get_symbolic_state')` that will search the reminding wrappers.
#   logger.warn(
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# terminated:  {'reached_goal': True, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# -----------------------------------
# | info/                |          |
# |    no_shield_action  | 0        |
# |    sum_opened_door   | 0        |
# |    sum_picked_up     | 0        |
# |    sum_ran_into_lava | 0        |
# |    sum_reached_goal  | 1        |
# | rollout/             |          |
# |    ep_len_mean       | 185      |
# |    ep_rew_mean       | -1.75    |
# | time/                |          |
# |    fps               | 40       |
# |    iterations        | 1        |
# |    time_elapsed      | 50       |
# |    total_timesteps   | 2048     |
# -----------------------------------
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# truncated:  {'reached_goal': False, 'ran_into_lava': False, 'opened_door': False, 'picked_up': False}
# ------------------------------------------
# | info/                   |              |
# |    no_shield_action     | 0            |
# |    sum_opened_door      | 0            |
# |    sum_picked_up        | 0            |
# |    sum_ran_into_lava    | 0            |
# |    sum_reached_goal     | 1            |
# | rollout/                |              |
# |    ep_len_mean          | 193          |
# |    ep_rew_mean          | -1.88        |
# | time/                   |              |
# |    fps                  | 17           |
# |    iterations           | 2            |
# |    time_elapsed         | 238          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0057517234 |
# |    clip_fraction        | 0.0133       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.917       |
# |    explained_variance   | -0.0275      |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0103      |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.000745    |
# |    value_loss           | 0.651        |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 62
#      60 if __name__ == '__main__':
#      61     print("Starting the training")
# ---> 62     main()
#
# Cell In[2], line 56, in main()
#      53 model.set_logger(logger)
#      54 steps = 400000
# ---> 56 model.learn(steps,callback=[InfoCallback()])
#
# File /opt/venv/lib/python3.10/site-packages/sb3_contrib/ppo_mask/ppo_mask.py:466, in MaskablePPO.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, use_masking, progress_bar)
#     463     if log_interval is not None and iteration % log_interval == 0:
#     464         self.dump_logs(iteration)
# --> 466     self.train()
#     468 callback.on_training_end()
#     470 return self
#
# File /opt/venv/lib/python3.10/site-packages/sb3_contrib/ppo_mask/ppo_mask.py:408, in MaskablePPO.train(self)
#     406     # Clip grad norm
#     407     th.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
# --> 408     self.policy.optimizer.step()
#     410 if not continue_training:
#     411     break
#
# File /opt/venv/lib/python3.10/site-packages/torch/optim/optimizer.py:517, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     512         else:
#     513             raise RuntimeError(
#     514                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     515             )
# --> 517 out = func(*args, **kwargs)
#     518 self._optimizer_step_code()
#     520 # call optimizer step post hooks
#
# File /opt/venv/lib/python3.10/site-packages/torch/optim/optimizer.py:82, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      80     torch.set_grad_enabled(self.defaults["differentiable"])
#      81     torch._dynamo.graph_break()
# ---> 82     ret = func(*args, **kwargs)
#      83 finally:
#      84     torch._dynamo.graph_break()
#
# File /opt/venv/lib/python3.10/site-packages/torch/optim/adam.py:247, in Adam.step(self, closure)
#     235     beta1, beta2 = group["betas"]
#     237     has_complex = self._init_group(
#     238         group,
#     239         params_with_grad,
#    (...)
#     244         state_steps,
#     245     )
# --> 247     adam(
#     248         params_with_grad,
#     249         grads,
#     250         exp_avgs,
#     251         exp_avg_sqs,
#     252         max_exp_avg_sqs,
#     253         state_steps,
#     254         amsgrad=group["amsgrad"],
#     255         has_complex=has_complex,
#     256         beta1=beta1,
#     257         beta2=beta2,
#     258         lr=group["lr"],
#     259         weight_decay=group["weight_decay"],
#     260         eps=group["eps"],
#     261         maximize=group["maximize"],
#     262         foreach=group["foreach"],
#     263         capturable=group["capturable"],
#     264         differentiable=group["differentiable"],
#     265         fused=group["fused"],
#     266         grad_scale=getattr(self, "grad_scale", None),
#     267         found_inf=getattr(self, "found_inf", None),
#     268         decoupled_weight_decay=group["decoupled_weight_decay"],
#     269     )
#     271 return loss
#
# File /opt/venv/lib/python3.10/site-packages/torch/optim/optimizer.py:150, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     148     return disabled_func(*args, **kwargs)
#     149 else:
# --> 150     return func(*args, **kwargs)
#
# File /opt/venv/lib/python3.10/site-packages/torch/optim/adam.py:953, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     950 else:
#     951     func = _single_tensor_adam
# --> 953 func(
#     954     params,
#     955     grads,
#     956     exp_avgs,
#     957     exp_avg_sqs,
#     958     max_exp_avg_sqs,
#     959     state_steps,
#     960     amsgrad=amsgrad,
#     961     has_complex=has_complex,
#     962     beta1=beta1,
#     963     beta2=beta2,
#     964     lr=lr,
#     965     weight_decay=weight_decay,
#     966     eps=eps,
#     967     maximize=maximize,
#     968     capturable=capturable,
#     969     differentiable=differentiable,
#     970     grad_scale=grad_scale,
#     971     found_inf=found_inf,
#     972     decoupled_weight_decay=decoupled_weight_decay,
#     973 )
#
# File /opt/venv/lib/python3.10/site-packages/torch/optim/adam.py:535, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     533         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     534     else:
# --> 535         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     537     param.addcdiv_(exp_avg, denom, value=-step_size)  # type: ignore[arg-type]
#     539 # Lastly, switch back to complex view
#
# KeyboardInterrupt:
